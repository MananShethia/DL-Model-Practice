# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
person_info = pd.read_csv('person_info.csv')

# %%
person_info
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
person = person_info.drop('Index', axis = 1)
person
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149      61
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %%
Heatmap is a two-dimensional visual representation of the variables. It is considered one of the best visual graphical 
representations when you want to show complex data. It is comprised of square boxes, and the x-axis and y-axis represent 
the variables. For correlation, each square box represents the level of correlation between the variable on the X-axis Vs. 
variable on the Y-axis. The annotations shown in each square box represent the correlation value. If you look across the 
matrix, the correlation value for weight and height is 0.00045, which indicates that these variables are highly correlated. 
Please note that if you look diagonally, the values will always be one as you are just comparing the variable with itself.

Regarding correlation:

1. Values closer to 1 show a high correlation, and values closer to 0 show the lowest correlation.
2. A positive correlation value shows that the variables are positively correlated. For example, taller individuals 
usually weigh more.
3. A negative correlation value shows that the variables are negatively correlated.

# %%
person_hw = person[['Height', 'Weight']]

# visualizing the data using heatmap
sns.heatmap(person_hw.corr(), annot = True)
sns.set(rc = {'figure.figsize': (40,40)})
# ax = sns.heatmap(person_hw)

# %%
Plot sns pair plot to visually represent the positive/negative correlation between the variables.

# %%
# create an default pairplot
sns.pairplot(person[['Height', 'Weight']])

# %%
Now, let's build a model that will predict the individual's weight based on height. 
Below are the steps to follow to create a model.

We are first splitting the dataset into train and test data sets. We will build the model based on the train data set and 
test it on the test dataset.

# %%
# create array for independent and dependent variables
X = person.iloc[:, 1:2].values
Y = person.iloc[:, 2].values

# splitting the variables as training and tesying
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size = 0.6, test_size = 0.4, random_state = 100)



print('Row Count of X_train table' + ' - ' + str(f'{len(X_train):,}'))
print('Row Count of y_train table' + ' - ' + str(f'{len(y_train):,}'))

print('Row Count of X_test table' + ' - ' + str(f'{len(X_test):,}'))
print('Row Count of X_test table' + ' - ' + str(f'{len(X_test):,}'))
# Out:
# Row Count of X_train table - 300
# Row Count of y_train table - 300
# Row Count of X_test table - 200
# Row Count of X_test table - 200

# %%
print('X_train --> ' + str(X_train))
print('X_test --> ' + str(X_test))
print('y_train --> ' + str(y_train))
print('y_test --> ' + str(y_test))
# Out:
# X_train --> [[172]
#  [184]
#  [170]
#  [181]
#  [181]
#  [151]
#  [196]
#  [181]
#  [172]
#  [164]
#  [173]
#  [143]
#  [140]
#  [159]
#  [142]
#  [188]
#  [184]
#  [150]
#  [161]
#  [188]
#  [160]
#  [166]
#  [178]
#  [181]
#  [153]
#  [158]
#  [178]
#  [190]
#  [190]
#  [189]
#  [174]
#  [185]
#  [142]
#  [190]
#  [181]
#  [166]
#  [177]
#  [195]
#  [164]
#  [183]
#  [162]
#  [185]
#  [140]
#  [179]
#  [182]
#  [159]
#  [147]
#  [145]
#  [140]
#  [165]
#  [149]
#  [188]
#  [183]
#  [182]
#  [192]
#  [182]
#  [163]
#  [169]
#  [151]
#  [193]
#  [141]
#  [169]
#  [195]
#  [156]
#  [184]
#  [167]
#  [178]
#  [150]
#  [181]
#  [148]
#  [184]
#  [198]
#  [179]
#  [172]
#  [163]
#  [159]
#  [186]
#  [192]
#  [181]
#  [154]
#  [181]
#  [186]
#  [169]
#  [192]
#  [191]
#  [190]
#  [182]
#  [188]
#  [157]
#  [186]
#  [177]
#  [178]
#  [162]
#  [179]
#  [176]
#  [152]
#  [177]
#  [191]
#  [188]
#  [145]
#  [172]
#  [149]
#  [154]
#  [159]
#  [160]
#  [172]
#  [141]
#  [147]
#  [166]
# ...

# %%
## Build a simple Linear Regression Model
Now, we are ready to build a simple linear regression model. Remember, the regression model predicts the continuous 
variables only. Like weight, sales, the number of births, etc. So, we should choose a regression model only when we have 
continuous dependent and independent variables.


How do we build the model? What packages do we need? We will be using existing python packages to build the model.


Below are the packages:
    Sklearn
    Statsmodel

    
Below is the equation for simple linear regression:
    Y = a + b.X
        where,  Y = dependent variable (weight)
                a = intercept
                b = slope of the line
                X = independent variable (height)
                

                
## Add intercept to the model
The Statsmodel library that we will be using for building the linear regression model will fit a line for our dataset. 
Now, let's input the intercept value using the Statsmodel library.

# %%
# importing statsmodel.api library from stamodel package
import statsmodels.api as sm

# adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

print('Intercept added to the linear regression model - ' + str(X_train_sm))
# Out:
# Intercept added to the linear regression model - [[  1. 172.]
#  [  1. 184.]
#  [  1. 170.]
#  [  1. 181.]
#  [  1. 181.]
#  [  1. 151.]
#  [  1. 196.]
#  [  1. 181.]
#  [  1. 172.]
#  [  1. 164.]
#  [  1. 173.]
#  [  1. 143.]
#  [  1. 140.]
#  [  1. 159.]
#  [  1. 142.]
#  [  1. 188.]
#  [  1. 184.]
#  [  1. 150.]
#  [  1. 161.]
#  [  1. 188.]
#  [  1. 160.]
#  [  1. 166.]
#  [  1. 178.]
#  [  1. 181.]
#  [  1. 153.]
#  [  1. 158.]
#  [  1. 178.]
#  [  1. 190.]
#  [  1. 190.]
#  [  1. 189.]
#  [  1. 174.]
#  [  1. 185.]
#  [  1. 142.]
#  [  1. 190.]
#  [  1. 181.]
#  [  1. 166.]
#  [  1. 177.]
#  [  1. 195.]
#  [  1. 164.]
#  [  1. 183.]
#  [  1. 162.]
#  [  1. 185.]
#  [  1. 140.]
#  [  1. 179.]
#  [  1. 182.]
#  [  1. 159.]
#  [  1. 147.]
#  [  1. 145.]
#  [  1. 140.]
#  [  1. 165.]
#  [  1. 149.]
#  [  1. 188.]
#  [  1. 183.]
#  [  1. 182.]
#  [  1. 192.]
#  [  1. 182.]
#  [  1. 163.]
#  [  1. 169.]
#  [  1. 151.]
#  [  1. 193.]
#  [  1. 141.]
#  [  1. 169.]
#  [  1. 195.]
# ...

# %%
## Fit the regression line
Now, let’s fit the regression line using the stats model.

# %%
# fitting the regression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# printing the parameters
lr.params

# linear regression summary
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6301
# Date:                Thu, 18 Aug 2022   Prob (F-statistic):              0.428
# Time:                        19:06:40   Log-Likelihood:                -1472.1
# No. Observations:                 300   AIC:                             2948.
# Df Residuals:                     298   BIC:                             2956.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        121.5675     20.338      5.977      0.000      81.543     161.592
# ...

# %%
## Understand the results
R-squared value is 0.002. This shows that 0.2% of the variance in the weight can be explained by height.


NOTE if :-  F statistic is pretty low, which shows that the model fit is statistically significant.
            example, 0.6301 is not low

        
The coefficient for height is -0.0945 and P-value is close to 0.43.
NOTE if :-  The coefficient for height is 7.7 and P-value is close to 0. This shows that the coefficient is statistically 
            significant.
        
        
Based on the summary, we can now derive the linear regression equation using intercept and slope.

Weight = 121.5675 + -0.0945 * height

# %%
## Plot the regression line using the equation:

# %%
# plot the regression line
import matplotlib.pyplot as plt
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.scatter(X_train, y_train)
plt.plot(X_train, 121.5675 + -0.0945 * X_train, 'r')
plt.show()

# %%
## Now predict the weight based on the height in the test dataset

# %%
# adding a constant to X_test
X_test_sm = sm.add_constant(X_test)

# predicting the y values corresponding to X_train_sm
y_test_pred = lr.predict(X_test_sm)

# printing the predicted values
y_test_pred
# Out:
# array([103.23374491, 104.65130352, 107.0139012 , 105.50183869,
#        103.04473709, 106.63588557, 107.86443637, 103.42275272,
#        105.59634259, 106.63588557, 105.6908465 , 104.93481524,
#        104.55679961, 104.3677918 , 104.84031133, 107.58092465,
#        103.98977617, 107.67542856, 102.76122537, 104.65130352,
#        103.04473709, 107.20290902, 106.44687776, 106.54138167,
#        104.3677918 , 105.87985431, 102.85572928, 106.16336604,
#        107.86443637, 104.74580743, 104.08428007, 107.58092465,
#        104.3677918 , 105.12382306, 103.139241  , 103.70626444,
#        103.98977617, 103.80076835, 107.95894028, 107.67542856,
#        105.6908465 , 107.76993246, 108.33695591, 103.89527226,
#        102.95023318, 106.25786994, 104.65130352, 105.97435822,
#        107.76993246, 106.73038948, 106.35237385, 104.08428007,
#        103.89527226, 104.17878398, 105.02931915, 105.50183869,
#        105.97435822, 103.139241  , 107.86443637, 103.89527226,
# ...

# %%
## What is r to the power of 2?

# %%
# importing r2_square
from sklearn.metrics import r2_score

# cheacking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# -0.010985567531003326

# %%
Our model still shows that the height can explain -1.09% of the variance in the weight for the test dataset. 
This score aligns with the training model r2. 

In this module, we have learned how to load the dataset and perform simple exploratory data analysis. For a given dataset, 
if we have a continuous dependent and independent variable, a simple linear regression statistical model can be used to 
predict the dependent variable.

# %%
## What is a Residual value?
So, you have learned in previously that we use algorithms to predict the future value based on the factors that impact the 
outcome. 
Now, as algorithms accuracy is only 80% – 90% on average, it is understandable that the algorithm will predict as 
close to the original value as possible. But there is always that residual (gap) between the actual value and expected 
value. Now, that gap/error in the prediction is called the residual.

# %% [markdown]
# Residual = Original Value – Predicted Value
#
# ![residual.png](attachment:residual.png)

# %%
Positive Residual Value: The residual is positive if the predicted value is less than the actual (original) value. 

Negative Residual Value: If the expected value is more than the actual value, the residual is negative.

# %%
## Residual Characteristics:

The number of residual values is the same as the total number of actual/predicted values. For example, if we predict the 
humidity percentage for 50 states, there are 50 actual values for each state. Corresponding to the actual values, we will 
have 50 predicted values. As the formula for determining the residual value is subtracting the predicted value from the 
actual value, the total number of residual values will be 50.

The mean value of the residuals should always be zero.
If you add all the residuals, the sum of the residuals will be zero.
Residuals should show a random distribution and should follow a bell-shaped pattern.

Now that we have seen how to calculate the residuals and the residual characteristics, let us understand why we need to 
check the residual?

An adequate model residuals should not show any patterns.
If the residuals show any patterns, that indicates that the model needs improvement.

# %% [markdown]
# ## Test for Residual Normality
#
# Residual plots: The residuals are plotted for linear regression models. These plots will tell us if we used a suitable
# model to analyze the data and also if there are any additional issues with the data that we need to address.
#
# The residual plot looks like the variance is the same across, and we don’t see any patterns.
#
# ![residual_plot.png](attachment:residual_plot.png)

# %% [markdown]
# There are multiple things to learn from the residual plot below. Firstly, we see a curve pattern, which indicates a nonlinear relationship in the original data. That shows that we need to consider a different statistical model for this data as the dependent and the independent variables show a nonlinear relationship. Secondly, the vertical spread indicates that we need to use a higher-order term or a transformation for the predictor variable.
#
# ![residual_plot_1.png](attachment:residual_plot_1.png)

# %% [markdown]
# The below graph shows a funnel-shaped residual plot. This shows the residual value increases as the predicted value increases. It violates the assumption of equal variance.
#
# ![residual_plot_2.png](attachment:residual_plot_2.png)
#
# Now that we have covered the basics on residuals, we will be including the residual plot checks on models we will create to understand the underlying issues with the data and the algorithms we use for building the models.
