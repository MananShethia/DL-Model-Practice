# %%
# !which python
# !python --version

# %env PYTHONPATH=
# Out:
# /usr/local/bin/python
# Python 3.9.16
# env: PYTHONPATH=

# %%
# !wget !wget https://repo.anaconda.com/miniconda/Miniconda3-4.9.2-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -y python=3.7
# Out:
# --2023-03-22 15:58:29--  http://!wget/
# Resolving !wget (!wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘!wget’
# --2023-03-22 15:58:29--  https://repo.anaconda.com/miniconda/Miniconda3-4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-03-22 15:58:29 ERROR 404: Not Found.
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
# done
# done
# installation finished.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.7
#
#
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 23.1.0

# %%
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.7.16
